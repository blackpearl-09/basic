# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data.csv')
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
df.drop(['Photo','Flag','Club Logo'], axis = 1, inplace=True)
df
# Out:
#        Unnamed: 0      ID                Name  Age Nationality  Overall  \
# 0               0  158023            L. Messi   31   Argentina       94
# 1               1   20801   Cristiano Ronaldo   33    Portugal       94
# 2               2  190871           Neymar Jr   26      Brazil       92
# 3               3  193080              De Gea   27       Spain       91
# 4               4  192985        K. De Bruyne   27     Belgium       91
# ...           ...     ...                 ...  ...         ...      ...
# 18202       18202  238813        J. Lundstram   19     England       47
# 18203       18203  243165  N. Christoffersson   19      Sweden       47
# 18204       18204  241638           B. Worman   16     England       47
# 18205       18205  246268      D. Walker-Rice   17     England       47
# 18206       18206  246269           G. Nugent   16     England       46
#
#        Potential                 Club    Value   Wage  ...  Composure Marking  \
# ...

# %%
df['Club'].value_counts()
# Out:
# RC Celta             33
# Manchester United    33
# Empoli               33
# AS Monaco            33
# Tottenham Hotspur    33
#                      ..
# Santos               20
# Vitória              20
# Sligo Rovers         19
# Limerick FC          19
# Derry City           18
# Name: Club, Length: 651, dtype: int64

# %%
df['Position'].value_counts()
# Out:
# ST     2152
# GK     2025
# CB     1778
# CM     1394
# LB     1322
# RB     1291
# RM     1124
# LM     1095
# CAM     958
# CDM     948
# RCB     662
# LCB     648
# LCM     395
# RCM     391
# LW      381
# RW      370
# RDM     248
# LDM     243
# LS      207
# RS      203
# RWB      87
# LWB      78
# CF       74
# RAM      21
# LAM      21
# RF       16
# LF       15
# Name: Position, dtype: int64

# %%
df['Position'] = df['Position'].replace(['CDM','LDM','RDM'],['DM','DM','DM'])
df['Position'] = df['Position'].replace(['CM','LCM','RCM'],['CM','CM','CM'])
df['Position'] = df['Position'].replace(['LAM','RAM','CAM'],['AM','AM','AM'])
df['Position'] = df['Position'].replace(['ST','LS','RS'],['ST','ST','ST'])
df['Position'] = df['Position'].replace(['CB','RCB','LCB'],['CB','CB','CB'])
df['Position'] = df['Position'].replace(['CB','RCB','LCB'],['CB','CB','CB'])
df['Position'] = df['Position'].replace(['CF','RF','LF'],['FW','FW','FW'])
df['Position'] = df['Position'].replace(['RWB','LWB'],['WB','WB'])
df['Position'].value_counts()
# Out:
# CB    3088
# ST    2562
# CM    2180
# GK    2025
# DM    1439
# LB    1322
# RB    1291
# RM    1124
# LM    1095
# AM    1000
# LW     381
# RW     370
# WB     165
# FW     105
# Name: Position, dtype: int64

# %%
df['Position'].value_counts().plot(kind = 'bar')

# %%
df['Wage'].max()
# Out:
# '€9K'

# %%
df['Potential'].describe()
# Out:
# count    18207.000000
# mean        71.307299
# std          6.136496
# min         48.000000
# 25%         67.000000
# 50%         71.000000
# 75%         75.000000
# max         95.000000
# Name: Potential, dtype: float64

# %%
df.boxplot(column = 'BallControl')

# %%
df['BallControl'].describe()
# Out:
# count    18159.000000
# mean        58.369459
# std         16.686595
# min          5.000000
# 25%         54.000000
# 50%         63.000000
# 75%         69.000000
# max         96.000000
# Name: BallControl, dtype: float64

# %%
df[(df['BallControl'] <= 54.0)]
df[(df['BallControl'] <= 54.0)  & (df['Position'] == 'GK')].count()
# Out:
#        Unnamed: 0      ID                Name  Age Nationality  Overall  \
# 3               3  193080              De Gea   27       Spain       91
# 9               9  200389            J. Oblak   25    Slovenia       90
# 18             18  192448       M. ter Stegen   26     Germany       89
# 19             19  192119         T. Courtois   26     Belgium       89
# 22             22  167495            M. Neuer   32     Germany       89
# ...           ...     ...                 ...  ...         ...      ...
# 18202       18202  238813        J. Lundstram   19     England       47
# 18203       18203  243165  N. Christoffersson   19      Sweden       47
# 18204       18204  241638           B. Worman   16     England       47
# 18205       18205  246268      D. Walker-Rice   17     England       47
# 18206       18206  246269           G. Nugent   16     England       46
#
#        Potential               Club   Value   Wage  ...  Composure Marking  \
# ...
